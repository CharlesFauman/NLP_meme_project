# %%
from PIL import Image, ImageOps
import numpy as np

# %%
image = Image.open("../collection/templates/Joseph Ducreux.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x775 at 0x22893C4C588>

# %%
ImageOps.fit(image, (300,300), Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x22893C4C550>

# %%
[x[0] for x in [tuple((0,1)), tuple((2,3)), tuple((4,5)), tuple((6,7))][0:3]]
# Out:
# [0, 2, 4]
